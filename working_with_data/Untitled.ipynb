# %% [markdown]
# # Importing library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv('D:\GitHub\ml.howtocode.com.bd\datasets\pima diabetes data\pima-data.csv')

# %% [markdown]
# # Viewing data

# %%
data_frame.shape
# Out:
# (768, 10)

# %%
data_frame.head(3)
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
#
#    age    skin diabetes
# 0   50  1.3790     True
# 1   31  1.1426    False
# 2   32  0.0000     True

# %%
data_frame.tail(4)
# Out:
#      num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  \
# 764         2           122            70         27        0  36.8
# 765         5           121            72         23      112  26.2
# 766         1           126            60          0        0  30.1
# 767         1            93            70         31        0  30.4
#
#      diab_pred  age    skin diabetes
# 764      0.340   27  1.0638    False
# 765      0.245   30  0.9062    False
# 766      0.349   47  0.0000     True
# 767      0.315   23  1.2214    False

# %% [markdown]
# # Checking for null data

# %%
data_frame.isnull()
# Out:
#     num_preg glucose_conc diastolic_bp thickness insulin    bmi diab_pred  \
# 0      False        False        False     False   False  False     False
# 1      False        False        False     False   False  False     False
# 2      False        False        False     False   False  False     False
# 3      False        False        False     False   False  False     False
# 4      False        False        False     False   False  False     False
# 5      False        False        False     False   False  False     False
# 6      False        False        False     False   False  False     False
# 7      False        False        False     False   False  False     False
# 8      False        False        False     False   False  False     False
# 9      False        False        False     False   False  False     False
# 10     False        False        False     False   False  False     False
# 11     False        False        False     False   False  False     False
# ...

# %%
data_frame.isnull().values
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %%
data_frame.isnull().values.any()
# Out:
# False

# %%
data_frame = pd.read_csv('D:\GitHub\ml.howtocode.com.bd\datasets\pima diabetes data\pima-data.csv')

# %%
data_frame.isnull().values.any()
# Out:
# True

# %%
def corr_heatmap(data_frame, size=11):
  # Getting correlation using Pandas
  correlation = data_frame.corr()

  # Dividing the plot into subplots for increasing size of plots
  fig, heatmap = plt.subplots(figsize=(size, size))

  # Plotting the correlation heatmap
  heatmap.matshow(correlation)

  # Adding xticks and yticks
  plt.xticks(range(len(correlation.columns)), correlation.columns)
  plt.yticks(range(len(correlation.columns)), correlation.columns)
    
  # Displaying the graph
  plt.show()

# %%
corr_heatmap(data_frame, 16)

# %%
del data_frame['skin']

# %%
data_frame.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age diabetes
# 0   50     True
# 1   31    False
# 2   32     True
# 3   21    False
# 4   33     True

# %%
map_diabetes = {True : 1, False : 0}
data_frame['diabetes'] = data_frame['diabetes'].map(map_diabetes)
data_frame.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes
# 0   50         1
# 1   31         0
# 2   32         1
# 3   21         0
# 4   33         1

# %%
num_true = 0.0
num_false = 0.0
for item in data_frame['diabetes']:
    if item == True:
        num_true += 1
    else:
        num_false += 1
        
percent_true = (num_true / (num_true + num_false)) * 100
percent_false = (num_false / (num_true + num_false)) * 100

print "Number of True Cases: {0} ({1:2.2f}%)".format(num_true, percent_true)
print "Number of False Cases: {0} ({1:2.2f}%)".format(num_false, percent_false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4a1c462feeb0> in <module>()
#       1 num_true = 0.0
#       2 num_false = 0.0
# ----> 3 for item in data_frame['diabetes']:
#       4     if item == True:
#       5         num_true += 1
#
# NameError: name 'data_frame' is not defined

# %% [markdown]
# # Data Splitting

# %%
from sklearn.cross_validation import train_test_split

# %%
feature_column_names = ['num_preg', 'glucose_conc', 'diastolic_bp', 'thickness', 'insulin', 'bmi', 'diab_prod', 'age']
predicted_class_name = ['diabetes']

# %% [markdown]
# #### Predictor features

# %%
X = data_frame[feature_column_names].values
Y = data_frame[predicted_class_name].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e75e03a8c3e9> in <module>()
# ----> 1 X = data_frame[feature_column_names].values
#       2 Y = data_frame[predicted_class_name].values
#
# NameError: name 'data_frame' is not defined
